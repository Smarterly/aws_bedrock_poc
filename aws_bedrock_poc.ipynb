# %%
import boto3
import json
import pandas as pd

# %%
session = boto3.Session(profile_name='prod_temp') # temp profile has region set to us-east-1

# %% [markdown]
# #### Use the S3 client to list the first object in our S3 bucket (just ensuring that boto3 is working correctly)

# %%
s3_client = session.client(service_name='s3', region_name='eu-west-1')

# %%
s3_client.list_objects_v2(Bucket='aws-glue-cushon-dw', MaxKeys=1)
# Out:
# {'ResponseMetadata': {'RequestId': 'D43D9JP1WNGPVYB5',
#   'HostId': 'lwyVnPWfXSJbXa+sSqhiLiQO4oqv9l2qnL+JAB4u5gPDTP0G1whtEbo9FKRY/SbSR2oxu7FzO9vNh7TIloTwQA==',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'lwyVnPWfXSJbXa+sSqhiLiQO4oqv9l2qnL+JAB4u5gPDTP0G1whtEbo9FKRY/SbSR2oxu7FzO9vNh7TIloTwQA==',
#    'x-amz-request-id': 'D43D9JP1WNGPVYB5',
#    'date': 'Wed, 15 May 2024 08:01:54 GMT',
#    'x-amz-bucket-region': 'eu-west-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': True,
#  'Contents': [{'Key': 'Unsaved/2022/05/26/3fd6d8f0-268b-43ed-aada-8eb96bc3a8e2.csv',
#    'LastModified': datetime.datetime(2022, 5, 26, 10, 9, 45, tzinfo=tzutc()),
#    'ETag': '"c8b44d8146e2c734310996945a6d9129"',
#    'Size': 295,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'aws-glue-cushon-dw',
#  'Prefix': '',
#  'MaxKeys': 1,
#  'EncodingType': 'url',
#  'KeyCount': 1,
#  'NextContinuationToken': '1x4xzDpnXpZj48fZ6nz8JXrCin7HiDbl9fGQc1X9twItdg8zwU1BofcbLFSWxwSlCGPj1NHKNCGAF3CDVc9dDspcNm3/BGtYdS4EW/K5vBUFaMA8Q74nBbuVSEaaemK7AVm3kMhBXPC4='}

# %% [markdown]
# ### Check what models are available for us to use via the list_foundation_models endpoint

# %% [markdown]
# This reference shows which models are available in which region: https://docs.aws.amazon.com/bedrock/latest/userguide/models-regions.html

# %%
# the bedrock service exposes some basic endpoints to list and get models
# reference: https://docs.aws.amazon.com/bedrock/latest/userguide/service_code_examples_bedrock_actions.html

bedrock_client = session.client(
    service_name='bedrock', 
    region_name='us-east-1'
)

# %%
# make the list easier to read using a pandas dataframe
pd.set_option("display.max_rows", None)
pd.DataFrame(bedrock_client.list_foundation_models()['modelSummaries'])
# Out:
#                                              modelArn  \
# 0   arn:aws:bedrock:us-east-1::foundation-model/am...
# 1   arn:aws:bedrock:us-east-1::foundation-model/am...
# 2   arn:aws:bedrock:us-east-1::foundation-model/am...
# 3   arn:aws:bedrock:us-east-1::foundation-model/am...
# 4   arn:aws:bedrock:us-east-1::foundation-model/am...
# 5   arn:aws:bedrock:us-east-1::foundation-model/am...
# 6   arn:aws:bedrock:us-east-1::foundation-model/am...
# 7   arn:aws:bedrock:us-east-1::foundation-model/am...
# 8   arn:aws:bedrock:us-east-1::foundation-model/am...
# 9   arn:aws:bedrock:us-east-1::foundation-model/am...
# 10  arn:aws:bedrock:us-east-1::foundation-model/am...
# 11  arn:aws:bedrock:us-east-1::foundation-model/am...
# 12  arn:aws:bedrock:us-east-1::foundation-model/am...
# 13  arn:aws:bedrock:us-east-1::foundation-model/am...
# 14  arn:aws:bedrock:us-east-1::foundation-model/am...
# 15  arn:aws:bedrock:us-east-1::foundation-model/st...
# 16  arn:aws:bedrock:us-east-1::foundation-model/st...
# 17  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 18  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 19  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 20  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 21  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 22  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 23  arn:aws:bedrock:us-east-1::foundation-model/ai...
# 24  arn:aws:bedrock:us-east-1::foundation-model/an...
# 25  arn:aws:bedrock:us-east-1::foundation-model/an...
# 26  arn:aws:bedrock:us-east-1::foundation-model/an...
# 27  arn:aws:bedrock:us-east-1::foundation-model/an...
# 28  arn:aws:bedrock:us-east-1::foundation-model/an...
# 29  arn:aws:bedrock:us-east-1::foundation-model/an...
# 30  arn:aws:bedrock:us-east-1::foundation-model/an...
# 31  arn:aws:bedrock:us-east-1::foundation-model/an...
# 32  arn:aws:bedrock:us-east-1::foundation-model/an...
# 33  arn:aws:bedrock:us-east-1::foundation-model/an...
# 34  arn:aws:bedrock:us-east-1::foundation-model/an...
# 35  arn:aws:bedrock:us-east-1::foundation-model/an...
# 36  arn:aws:bedrock:us-east-1::foundation-model/an...
# 37  arn:aws:bedrock:us-east-1::foundation-model/an...
# 38  arn:aws:bedrock:us-east-1::foundation-model/co...
# 39  arn:aws:bedrock:us-east-1::foundation-model/co...
# 40  arn:aws:bedrock:us-east-1::foundation-model/co...
# 41  arn:aws:bedrock:us-east-1::foundation-model/co...
# 42  arn:aws:bedrock:us-east-1::foundation-model/co...
# 43  arn:aws:bedrock:us-east-1::foundation-model/co...
# 44  arn:aws:bedrock:us-east-1::foundation-model/co...
# 45  arn:aws:bedrock:us-east-1::foundation-model/co...
# 46  arn:aws:bedrock:us-east-1::foundation-model/co...
# 47  arn:aws:bedrock:us-east-1::foundation-model/co...
# 48  arn:aws:bedrock:us-east-1::foundation-model/me...
# 49  arn:aws:bedrock:us-east-1::foundation-model/me...
# 50  arn:aws:bedrock:us-east-1::foundation-model/me...
# 51  arn:aws:bedrock:us-east-1::foundation-model/me...
# 52  arn:aws:bedrock:us-east-1::foundation-model/me...
# 53  arn:aws:bedrock:us-east-1::foundation-model/me...
# 54  arn:aws:bedrock:us-east-1::foundation-model/me...
# 55  arn:aws:bedrock:us-east-1::foundation-model/me...
# 56  arn:aws:bedrock:us-east-1::foundation-model/me...
# 57  arn:aws:bedrock:us-east-1::foundation-model/me...
# 58  arn:aws:bedrock:us-east-1::foundation-model/mi...
# 59  arn:aws:bedrock:us-east-1::foundation-model/mi...
# 60  arn:aws:bedrock:us-east-1::foundation-model/mi...
#
#                                          modelId  \
# 0                         amazon.titan-tg1-large
# 1              amazon.titan-image-generator-v1:0
# 2                amazon.titan-image-generator-v1
# 3                 amazon.titan-text-premier-v1:0
# 4                  amazon.titan-embed-g1-text-02
# 5                 amazon.titan-text-lite-v1:0:4k
# 6                      amazon.titan-text-lite-v1
# 7              amazon.titan-text-express-v1:0:8k
# 8                   amazon.titan-text-express-v1
# 9                amazon.titan-embed-text-v1:2:8k
# 10                    amazon.titan-embed-text-v1
# 11               amazon.titan-embed-text-v2:0:8k
# 12                  amazon.titan-embed-text-v2:0
# 13                 amazon.titan-embed-image-v1:0
# 14                   amazon.titan-embed-image-v1
# 15            stability.stable-diffusion-xl-v1:0
# 16              stability.stable-diffusion-xl-v1
# 17                       ai21.j2-grande-instruct
# 18                        ai21.j2-jumbo-instruct
# 19                                   ai21.j2-mid
# 20                                ai21.j2-mid-v1
# 21                                 ai21.j2-ultra
# 22                         ai21.j2-ultra-v1:0:8k
# 23                              ai21.j2-ultra-v1
# 24            anthropic.claude-instant-v1:2:100k
# 25                   anthropic.claude-instant-v1
# 26                     anthropic.claude-v2:0:18k
# 27                    anthropic.claude-v2:0:100k
# 28                     anthropic.claude-v2:1:18k
# 29                    anthropic.claude-v2:1:200k
# 30                         anthropic.claude-v2:1
# 31                           anthropic.claude-v2
# 32   anthropic.claude-3-sonnet-20240229-v1:0:28k
# 33  anthropic.claude-3-sonnet-20240229-v1:0:200k
# 34       anthropic.claude-3-sonnet-20240229-v1:0
# 35    anthropic.claude-3-haiku-20240307-v1:0:48k
# 36   anthropic.claude-3-haiku-20240307-v1:0:200k
# 37        anthropic.claude-3-haiku-20240307-v1:0
# 38                  cohere.command-text-v14:7:4k
# 39                       cohere.command-text-v14
# 40                         cohere.command-r-v1:0
# 41                    cohere.command-r-plus-v1:0
# 42            cohere.command-light-text-v14:7:4k
# 43                 cohere.command-light-text-v14
# 44                 cohere.embed-english-v3:0:512
# 45                       cohere.embed-english-v3
# 46            cohere.embed-multilingual-v3:0:512
# 47                  cohere.embed-multilingual-v3
# 48                  meta.llama2-13b-chat-v1:0:4k
# 49                       meta.llama2-13b-chat-v1
# 50                  meta.llama2-70b-chat-v1:0:4k
# 51                       meta.llama2-70b-chat-v1
# 52                       meta.llama2-13b-v1:0:4k
# 53                            meta.llama2-13b-v1
# 54                       meta.llama2-70b-v1:0:4k
# 55                            meta.llama2-70b-v1
# 56                  meta.llama3-8b-instruct-v1:0
# 57                 meta.llama3-70b-instruct-v1:0
# 58              mistral.mistral-7b-instruct-v0:2
# 59            mistral.mixtral-8x7b-instruct-v0:1
# 60               mistral.mistral-large-2402-v1:0
#
#                          modelName  providerName inputModalities  \
# 0                 Titan Text Large        Amazon          [TEXT]
# 1         Titan Image Generator G1        Amazon   [TEXT, IMAGE]
# 2         Titan Image Generator G1        Amazon   [TEXT, IMAGE]
# 3          Titan Text G1 - Premier        Amazon          [TEXT]
# 4         Titan Text Embeddings v2        Amazon          [TEXT]
# 5             Titan Text G1 - Lite        Amazon          [TEXT]
# 6             Titan Text G1 - Lite        Amazon          [TEXT]
# 7          Titan Text G1 - Express        Amazon          [TEXT]
# 8          Titan Text G1 - Express        Amazon          [TEXT]
# 9       Titan Embeddings G1 - Text        Amazon          [TEXT]
# 10      Titan Embeddings G1 - Text        Amazon          [TEXT]
# 11        Titan Text Embeddings V2        Amazon          [TEXT]
# 12        Titan Text Embeddings V2        Amazon          [TEXT]
# 13  Titan Multimodal Embeddings G1        Amazon   [TEXT, IMAGE]
# 14  Titan Multimodal Embeddings G1        Amazon   [TEXT, IMAGE]
# 15                        SDXL 1.0  Stability AI   [TEXT, IMAGE]
# 16                        SDXL 1.0  Stability AI   [TEXT, IMAGE]
# 17              J2 Grande Instruct     AI21 Labs          [TEXT]
# 18               J2 Jumbo Instruct     AI21 Labs          [TEXT]
# 19                  Jurassic-2 Mid     AI21 Labs          [TEXT]
# 20                  Jurassic-2 Mid     AI21 Labs          [TEXT]
# 21                Jurassic-2 Ultra     AI21 Labs          [TEXT]
# 22                Jurassic-2 Ultra     AI21 Labs          [TEXT]
# 23                Jurassic-2 Ultra     AI21 Labs          [TEXT]
# 24                  Claude Instant     Anthropic          [TEXT]
# 25                  Claude Instant     Anthropic          [TEXT]
# 26                          Claude     Anthropic          [TEXT]
# 27                          Claude     Anthropic          [TEXT]
# 28                          Claude     Anthropic          [TEXT]
# 29                          Claude     Anthropic          [TEXT]
# 30                          Claude     Anthropic          [TEXT]
# 31                          Claude     Anthropic          [TEXT]
# 32                 Claude 3 Sonnet     Anthropic   [TEXT, IMAGE]
# 33                 Claude 3 Sonnet     Anthropic   [TEXT, IMAGE]
# 34                 Claude 3 Sonnet     Anthropic   [TEXT, IMAGE]
# 35                  Claude 3 Haiku     Anthropic   [TEXT, IMAGE]
# 36                  Claude 3 Haiku     Anthropic   [TEXT, IMAGE]
# 37                  Claude 3 Haiku     Anthropic   [TEXT, IMAGE]
# 38                         Command        Cohere          [TEXT]
# 39                         Command        Cohere          [TEXT]
# 40                       Command R        Cohere          [TEXT]
# 41                      Command R+        Cohere          [TEXT]
# 42                   Command Light        Cohere          [TEXT]
# 43                   Command Light        Cohere          [TEXT]
# 44                   Embed English        Cohere          [TEXT]
# 45                   Embed English        Cohere          [TEXT]
# 46              Embed Multilingual        Cohere          [TEXT]
# 47              Embed Multilingual        Cohere          [TEXT]
# 48                Llama 2 Chat 13B          Meta          [TEXT]
# 49                Llama 2 Chat 13B          Meta          [TEXT]
# 50                Llama 2 Chat 70B          Meta          [TEXT]
# 51                Llama 2 Chat 70B          Meta          [TEXT]
# 52                     Llama 2 13B          Meta          [TEXT]
# 53                     Llama 2 13B          Meta          [TEXT]
# 54                     Llama 2 70B          Meta          [TEXT]
# 55                     Llama 2 70B          Meta          [TEXT]
# 56             Llama 3 8B Instruct          Meta          [TEXT]
# 57            Llama 3 70B Instruct          Meta          [TEXT]
# 58             Mistral 7B Instruct    Mistral AI          [TEXT]
# 59           Mixtral 8x7B Instruct    Mistral AI          [TEXT]
# 60                   Mistral Large    Mistral AI          [TEXT]
#
#    outputModalities responseStreamingSupported  \
# 0            [TEXT]                       True
# 1           [IMAGE]                        NaN
# 2           [IMAGE]                        NaN
# 3            [TEXT]                       True
# 4       [EMBEDDING]                        NaN
# 5            [TEXT]                       True
# 6            [TEXT]                       True
# 7            [TEXT]                       True
# 8            [TEXT]                       True
# 9       [EMBEDDING]                      False
# 10      [EMBEDDING]                      False
# 11      [EMBEDDING]                      False
# 12      [EMBEDDING]                      False
# 13      [EMBEDDING]                        NaN
# 14      [EMBEDDING]                        NaN
# 15          [IMAGE]                        NaN
# 16          [IMAGE]                        NaN
# 17           [TEXT]                      False
# 18           [TEXT]                      False
# 19           [TEXT]                      False
# 20           [TEXT]                      False
# 21           [TEXT]                      False
# 22           [TEXT]                      False
# 23           [TEXT]                      False
# 24           [TEXT]                       True
# 25           [TEXT]                       True
# 26           [TEXT]                       True
# 27           [TEXT]                       True
# 28           [TEXT]                       True
# 29           [TEXT]                       True
# 30           [TEXT]                       True
# 31           [TEXT]                       True
# 32           [TEXT]                       True
# 33           [TEXT]                       True
# 34           [TEXT]                       True
# 35           [TEXT]                       True
# 36           [TEXT]                       True
# 37           [TEXT]                       True
# 38           [TEXT]                       True
# 39           [TEXT]                       True
# 40           [TEXT]                       True
# 41           [TEXT]                       True
# 42           [TEXT]                       True
# 43           [TEXT]                       True
# 44      [EMBEDDING]                      False
# 45      [EMBEDDING]                      False
# 46      [EMBEDDING]                      False
# 47      [EMBEDDING]                      False
# 48           [TEXT]                       True
# 49           [TEXT]                       True
# 50           [TEXT]                       True
# 51           [TEXT]                       True
# 52           [TEXT]                       True
# 53           [TEXT]                       True
# 54           [TEXT]                       True
# 55           [TEXT]                       True
# 56           [TEXT]                       True
# 57           [TEXT]                       True
# 58           [TEXT]                       True
# 59           [TEXT]                       True
# 60           [TEXT]                       True
#
#                   customizationsSupported inferenceTypesSupported  \
# 0                                      []             [ON_DEMAND]
# 1                           [FINE_TUNING]           [PROVISIONED]
# 2                                      []             [ON_DEMAND]
# 3                                      []             [ON_DEMAND]
# 4                                      []             [ON_DEMAND]
# 5   [FINE_TUNING, CONTINUED_PRE_TRAINING]           [PROVISIONED]
# 6                                      []             [ON_DEMAND]
# 7   [FINE_TUNING, CONTINUED_PRE_TRAINING]           [PROVISIONED]
# 8                                      []             [ON_DEMAND]
# 9                                      []           [PROVISIONED]
# 10                                     []             [ON_DEMAND]
# 11                                     []                      []
# 12                                     []             [ON_DEMAND]
# 13                          [FINE_TUNING]           [PROVISIONED]
# 14                                     []             [ON_DEMAND]
# 15                                     []           [PROVISIONED]
# 16                                     []             [ON_DEMAND]
# 17                                     []             [ON_DEMAND]
# 18                                     []             [ON_DEMAND]
# 19                                     []             [ON_DEMAND]
# 20                                     []             [ON_DEMAND]
# 21                                     []             [ON_DEMAND]
# 22                                     []           [PROVISIONED]
# 23                                     []             [ON_DEMAND]
# 24                                     []           [PROVISIONED]
# 25                                     []             [ON_DEMAND]
# 26                                     []           [PROVISIONED]
# 27                                     []           [PROVISIONED]
# 28                                     []           [PROVISIONED]
# 29                                     []           [PROVISIONED]
# 30                                     []             [ON_DEMAND]
# 31                                     []             [ON_DEMAND]
# 32                                     []           [PROVISIONED]
# 33                                     []           [PROVISIONED]
# 34                                     []             [ON_DEMAND]
# 35                                     []           [PROVISIONED]
# 36                                     []           [PROVISIONED]
# 37                                     []             [ON_DEMAND]
# 38                          [FINE_TUNING]           [PROVISIONED]
# 39                                     []             [ON_DEMAND]
# 40                                     []             [ON_DEMAND]
# 41                                     []             [ON_DEMAND]
# 42                          [FINE_TUNING]           [PROVISIONED]
# 43                                     []             [ON_DEMAND]
# 44                                     []           [PROVISIONED]
# 45                                     []             [ON_DEMAND]
# 46                                     []           [PROVISIONED]
# 47                                     []             [ON_DEMAND]
# 48                                     []           [PROVISIONED]
# 49                                     []             [ON_DEMAND]
# 50                                     []                      []
# 51                                     []             [ON_DEMAND]
# 52                          [FINE_TUNING]                      []
# 53                                     []                      []
# 54                          [FINE_TUNING]                      []
# 55                                     []                      []
# 56                                     []             [ON_DEMAND]
# 57                                     []             [ON_DEMAND]
# 58                                     []             [ON_DEMAND]
# 59                                     []             [ON_DEMAND]
# 60                                     []             [ON_DEMAND]
#
#           modelLifecycle
# 0   {'status': 'ACTIVE'}
# 1   {'status': 'ACTIVE'}
# 2   {'status': 'ACTIVE'}
# 3   {'status': 'ACTIVE'}
# 4   {'status': 'ACTIVE'}
# 5   {'status': 'ACTIVE'}
# 6   {'status': 'ACTIVE'}
# 7   {'status': 'ACTIVE'}
# 8   {'status': 'ACTIVE'}
# 9   {'status': 'ACTIVE'}
# 10  {'status': 'ACTIVE'}
# 11  {'status': 'ACTIVE'}
# 12  {'status': 'ACTIVE'}
# 13  {'status': 'ACTIVE'}
# 14  {'status': 'ACTIVE'}
# 15  {'status': 'ACTIVE'}
# 16  {'status': 'ACTIVE'}
# 17  {'status': 'ACTIVE'}
# 18  {'status': 'ACTIVE'}
# 19  {'status': 'ACTIVE'}
# 20  {'status': 'ACTIVE'}
# 21  {'status': 'ACTIVE'}
# 22  {'status': 'ACTIVE'}
# 23  {'status': 'ACTIVE'}
# 24  {'status': 'ACTIVE'}
# 25  {'status': 'ACTIVE'}
# 26  {'status': 'ACTIVE'}
# 27  {'status': 'ACTIVE'}
# 28  {'status': 'ACTIVE'}
# 29  {'status': 'ACTIVE'}
# 30  {'status': 'ACTIVE'}
# 31  {'status': 'ACTIVE'}
# 32  {'status': 'ACTIVE'}
# 33  {'status': 'ACTIVE'}
# 34  {'status': 'ACTIVE'}
# 35  {'status': 'ACTIVE'}
# 36  {'status': 'ACTIVE'}
# 37  {'status': 'ACTIVE'}
# 38  {'status': 'ACTIVE'}
# 39  {'status': 'ACTIVE'}
# 40  {'status': 'ACTIVE'}
# 41  {'status': 'ACTIVE'}
# 42  {'status': 'ACTIVE'}
# 43  {'status': 'ACTIVE'}
# 44  {'status': 'ACTIVE'}
# 45  {'status': 'ACTIVE'}
# 46  {'status': 'ACTIVE'}
# 47  {'status': 'ACTIVE'}
# 48  {'status': 'ACTIVE'}
# 49  {'status': 'ACTIVE'}
# 50  {'status': 'ACTIVE'}
# 51  {'status': 'ACTIVE'}
# 52  {'status': 'ACTIVE'}
# 53  {'status': 'ACTIVE'}
# 54  {'status': 'ACTIVE'}
# 55  {'status': 'ACTIVE'}
# 56  {'status': 'ACTIVE'}
# 57  {'status': 'ACTIVE'}
# 58  {'status': 'ACTIVE'}
# 59  {'status': 'ACTIVE'}
# 60  {'status': 'ACTIVE'}

# %% [markdown]
# ### Managing conversation context

# %% [markdown]
# Very basic class to keep track of the conversation context, like a very basic LangChain

# %%
class conversation:
    def __init__(self, model_id) :
        # model_id recognised by Bedrock
        # note we should extend the class to handle different LLMs (e.g. required model parameters and response JSON structures can be different for each model)
        # this reference provides code example for every single model so we'd know which parameter to pass through: https://docs.aws.amazon.com/bedrock/latest/userguide/service_code_examples_bedrock-runtime_invoke_model_examples.html
        self.model_id = model_id 
        self.conversation_history = [] # list of dictionaries, each dict contains the name of the conversation party and what's been said
        
        # init the bedrock-runtime service which exposes endpoints for invoking models
        # https://docs.aws.amazon.com/bedrock/latest/userguide/service_code_examples_bedrock-runtime.html
        self.boto_session = boto3.Session(profile_name='prod_temp')
        self.bedrock_runtime_client = self.boto_session.client(
            service_name='bedrock-runtime', 
            region_name='us-east-1',
        )
    
    # add a human prompt to the conversation
    def prompt(self, party_name, chat_message):
        conversation_part = {
            'character': party_name,
            'chat_message' : chat_message
        }
        self.conversation_history.append(conversation_part)
        print(party_name + ": " + chat_message)
    
    # invoke LLM
    def invoke_model(self):
        response = self.bedrock_runtime_client.invoke_model(
            body=json.dumps({
                "prompt": self.get_full_history_prompt() + "\n\nAssistant:",
                "temperature": 0.7,
                "top_p": 0.9,
            }), 
            modelId=self.model_id, 
            accept='application/json', 
            contentType='application/json'
        )
        self.process_response(response)

    # process response from LLM
    # TODO handle different models
    def process_response(self, response):
        response_body = json.loads(response.get('body').read())
        self.prompt('Assistant', response_body['generation'])
        #return response_body['generation']

    # convert entire conversation history to a single prompt for LLM
    def get_full_history_prompt(self):
        list_conversation_context = [msg['character'] + ": " + msg['chat_message'] for msg in self.conversation_history]
        return "\n\n".join(list_conversation_context)

# %% [markdown]
# ### Example model invocation

# %%
convo = conversation('meta.llama3-70b-instruct-v1:0')

# %%
convo.prompt("Human", "Can you tell me what is a large language model?")
# Out:
# Human: Can you tell me what is a large language model?

# %%
convo.invoke_model()
# Out:
# Assistant:  A large language model is a type of artificial neural network designed to process and understand human language. These models are trained on vast amounts of text data and can generate language outputs that are coherent and natural-sounding.
#
# Large language models are typically characterized by their massive scale, a large number of parameters, and the ability to learn complex patterns in language. They are often trained using a self-supervised learning approach, where the model predicts the next word in a sequence of text given the context of the previous words.
#
# Some key features of large language models include:
#
# 1. **Scalability**: They can process and generate text of arbitrary length, making them suitable for a wide range of applications.
# 2. **Contextual understanding**: They can capture subtle nuances in language, including context, tone, and sentiment.
# 3. **Generation capabilities**: They can generate text that is coherent, fluent, and often indistinguishable from human-written text.
# 4. **Multitask learning**: They can be fine-tuned for specific tasks, such as language translation, question-answering, or text summarization.
#
# Examples of large language models include:
#
# * BERT (Bidirectional Encoder Representations from Transformers)
# * RoBERTa (Robustly Optimized BERT Pretraining Approach)
# * XLNet (Extreme Language Modeling)
# * Transformers (such as the original Transformer model and its variants)
#
# These models have achieved state-of-the-art results in many natural language processing (NLP) tasks and have numerous applications in areas like:
#
# * Language translation
# * Text summarization
# * Chatbots and conversational AI
# * Sentiment analysis
# * Question-answering systems
# * Content generation (e.g., article writing, product descriptions)
#
# The development of large language models has been a significant breakthrough in NLP, enabling machines to better understand and generate human language.

# %%
convo.prompt("Human", "Thats awesome, can you summarise that into a single sentence please?")
# Out:
# Human: Thats awesome, can you summarise that into a single sentence please?

# %%
convo.invoke_model()
# Out:
# Assistant:  A large language model is a type of artificial neural network trained on vast amounts of text data to process and understand human language, capable of generating coherent and natural-sounding text outputs.

# %%
convo.prompt("Human", "Nice, now can you instead summarise it into 3 bullet points for a presentation I am writing?")
# Out:
# Human: Nice, now can you instead summarise it into 3 bullet points for a presentation I am writing?

# %%
convo.invoke_model()
# Out:
# Assistant:  Here are three bullet points summarizing large language models:
#
# • **Scalability and Contextual Understanding**: Large language models can process and generate text of arbitrary length, capturing subtle nuances in language, including context, tone, and sentiment.
# • **Generation Capabilities**: These models can generate text that is coherent, fluent, and often indistinguishable from human-written text, making them suitable for a wide range of applications.
# • **Multitask Learning and Applications**: Large language models can be fine-tuned for specific tasks, such as language translation, question-answering, or text summarization, and have numerous applications in areas like chatbots, content generation, and sentiment analysis.

# %%
# we can have a look at the full history at any time
# this needs to be part of the application state if our frontend needs to support full conversations (i.e. not one-shot use cases)
convo.conversation_history
# Out:
# [{'character': 'Human',
#   'chat_message': 'Can you tell me what is a large language model?'},
#  {'character': 'Assistant',
#   'chat_message': ' A large language model is a type of artificial neural network designed to process and understand human language. These models are trained on vast amounts of text data and can generate language outputs that are coherent and natural-sounding.\n\nLarge language models are typically characterized by their massive scale, a large number of parameters, and the ability to learn complex patterns in language. They are often trained using a self-supervised learning approach, where the model predicts the next word in a sequence of text given the context of the previous words.\n\nSome key features of large language models include:\n\n1. **Scalability**: They can process and generate text of arbitrary length, making them suitable for a wide range of applications.\n2. **Contextual understanding**: They can capture subtle nuances in language, including context, tone, and sentiment.\n3. **Generation capabilities**: They can generate text that is coherent, fluent, and often indistinguishable from human-written text.\n4. **Multitask learning**: They can be fine-tuned for specific tasks, such as language translation, question-answering, or text summarization.\n\nExamples of large language models include:\n\n* BERT (Bidirectional Encoder Representations from Transformers)\n* RoBERTa (Robustly Optimized BERT Pretraining Approach)\n* XLNet (Extreme Language Modeling)\n* Transformers (such as the original Transformer model and its variants)\n\nThese models have achieved state-of-the-art results in many natural language processing (NLP) tasks and have numerous applications in areas like:\n\n* Language translation\n* Text summarization\n* Chatbots and conversational AI\n* Sentiment analysis\n* Question-answering systems\n* Content generation (e.g., article writing, product descriptions)\n\nThe development of large language models has been a significant breakthrough in NLP, enabling machines to better understand and generate human language.'},
#  {'character': 'Human',
#   'chat_message': 'Thats awesome, can you summarise that into a single sentence please?'},
#  {'character': 'Assistant',
#   'chat_message': ' A large language model is a type of artificial neural network trained on vast amounts of text data to process and understand human language, capable of generating coherent and natural-sounding text outputs.'},
#  {'character': 'Human',
#   'chat_message': 'Nice, now can you instead summarise it into 3 bullet points for a presentation I am writing?'},
#  {'character': 'Assistant',
#   'chat_message': ' Here are three bullet points summarizing large language models:\n\n• **Scalability and Contextual Understanding**: Large language models can process and generate text of arbitrary length, capturing subtle nuances in language, including context, tone, and sentiment.\n• **Generation Capabilities**: These models can generate text that is coherent, fluent, and often indistinguishable from human-written text, making them suitable for a wide range of applications.\n• **Multitask Learning and Applications**: Large language models can be fine-tuned for specific tasks, such as language translation, question-answering, or text summarization, and have numerous applications in areas like chatbots, content generation, and sentiment analysis.'}]
